# %%
from data import data_utils

list_ids, labels = data_utils.parse_dataset()

print('Number of training examples: ', len(list_ids))
print('Number of labels: ', len(labels))
print('Labels: ', labels)
print('Sample list ID: ', list_ids[0])
# Out:
# Number of training examples:  1021961
# Number of labels:  7
# Labels:  {'angel', 'airplane', 'ambulance', 'The Great Wall of China', 'The Eiffel Tower', 'The Mona Lisa', 'alarm clock'}
# Sample list ID:  The Great Wall of China/4626156441567232.ndjson

# %%
import matplotlib.pyplot as plt
import numpy as np

from data import datasets

num_images_to_generate = 4
nums = np.random.randint(2, 4, num_images_to_generate)
quick_draw_dataset = datasets.QuickDrawDataset(list_ids, labels)
for i, num in enumerate(nums):
    sketch, labels = quick_draw_dataset.get_random_composite_drawing(num)
    plt.subplot(2, 2, i + 1)
    plt.imshow(data_utils.decode_drawing(sketch))
    plt.axis('off')
