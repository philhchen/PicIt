# %%
from data import data_utils, datasets

quick_draw_dataset = datasets.QuickDrawDataset()

print('Number of training examples: ', len(quick_draw_dataset))
print('Number of labels: ', len(quick_draw_dataset.labels_to_indices))
print('Labels: ', quick_draw_dataset.labels_to_indices.keys())
print('Sample list ID: ', quick_draw_dataset.list_IDs[0])

# %load_ext autoreload
# %autoreload 2
# Out:
# Number of training examples:  1635853
# Number of labels:  12
# Labels:  dict_keys(['apple', 'alarm clock', 'airplane', 'ant', 'angel', 'asparagus', 'ambulance', 'axe', 'anvil', 'animal migration', 'arm', 'aircraft carrier'])
# Sample list ID:  animal migration/4975017072787456.ndjson

# %%
import matplotlib.pyplot as plt
import numpy as np

num_images_to_generate = 1
nums = np.random.randint(2, 8, num_images_to_generate)
for i, num in enumerate(nums):
    sketch, boxes, segmentations, sketch_labels = quick_draw_dataset.get_random_composite_drawing(num)
    plt.subplot(1, 1, i + 1)
    plt.imshow(data_utils.decode_drawing(sketch))
    plt.axis('off')

# %%
num_images_to_generate = 10
data_splits = [0.7, 0.2, 0.1]
for i, mode in enumerate(['train', 'val', 'test']):
    datasets.create_composite_dataset((int)(num_images_to_generate * data_splits[i]), mode, quick_draw_dataset)
