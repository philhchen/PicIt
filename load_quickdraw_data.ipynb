# %%
from data import data_utils, datasets

quick_draw_dataset = datasets.QuickDrawDataset()

print('Number of training examples: ', len(quick_draw_dataset))
print('Number of labels: ', len(quick_draw_dataset.labels_to_indices))
print('Labels: ', quick_draw_dataset.labels_to_indices.keys())
print('Sample list ID: ', quick_draw_dataset.list_IDs[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ed8f674f8129> in <module>
#       1 from data import data_utils, datasets
#       2
# ----> 3 quick_draw_dataset = datasets.QuickDrawDataset()
#       4
#       5 print('Number of training examples: ', len(quick_draw_dataset))
#
# ~/Projects/PicIt/data/datasets.py in __init__(self, root, img_size)
#      26         @param img_size - int: the size to convert images in the dataset
#      27         """
# ---> 28         self.list_IDs, self.labels = data_utils.parse_dataset(path=root,
#      29                                                               decode=None)
#      30         self.root = root
#
# NameError: name 'data_utils' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

from data import datasets

num_images_to_generate = 1
nums = np.random.randint(2, 4, num_images_to_generate)
for i, num in enumerate(nums):
    sketch, sketch_labels = quick_draw_dataset.get_random_composite_drawing(num)
    plt.subplot(1, 1, i + 1)
    plt.imshow(data_utils.decode_drawing(sketch))
    plt.axis('off')

# %%
from torchvision.datasets import ImageFolder
from data import data_utils
# test_dataset = ImageFolder('/Users/phil/Projects/PicIt/dataset/raw')
# res = data_utils.parse_label("airplane.ndjson", path="/Users/phil/Projects/PicIt/dataset/raw", decode='jpg')
list_ids, labels = data_utils.parse_dataset(decode='jpg', early_return=False)
